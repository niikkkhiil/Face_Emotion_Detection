# %%
# !wget https://www.dropbox.com/s/nilt43hyl1dx82k/dataset.zip?dl=0
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip dataset.zip?dl=0
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\nikhil\appdata\local\programs\python\python310\lib\site-packages (1.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nikhil\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nikhil\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\nikhil\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.22.1)
# Requirement already satisfied: six>=1.5 in c:\users\nikhil\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "D:\\Face Emotion recognition\\Emotion-detection\\train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 350 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "D:\\Face Emotion recognition\\Emotion-detection\\train", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 350 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_11808\564963302.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 10.4099 - accuracy: 0.1969
# Epoch 1: val_accuracy improved from -inf to 0.52344, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 10.4099 - accuracy: 0.1969 - val_loss: 4.8534 - val_accuracy: 0.5234
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 4.5542 - accuracy: 0.5786
# Epoch 2: val_accuracy improved from 0.52344 to 0.72656, saving model to best_model.h5
# 10/10 [==============================] - 17s 2s/step - loss: 4.5542 - accuracy: 0.5786 - val_loss: 1.6727 - val_accuracy: 0.7266
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 2.7301 - accuracy: 0.6698
# Epoch 3: val_accuracy improved from 0.72656 to 0.75391, saving model to best_model.h5
# 10/10 [==============================] - 17s 2s/step - loss: 2.7301 - accuracy: 0.6698 - val_loss: 1.7223 - val_accuracy: 0.7539
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 1.1531 - accuracy: 0.8082
# Epoch 4: val_accuracy improved from 0.75391 to 0.86719, saving model to best_model.h5
# 10/10 [==============================] - 16s 2s/step - loss: 1.1531 - accuracy: 0.8082 - val_loss: 0.7745 - val_accuracy: 0.8672
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6754 - accuracy: 0.8742
# Epoch 5: val_accuracy improved from 0.86719 to 0.91406, saving model to best_model.h5
# 10/10 [==============================] - 15s 2s/step - loss: 0.6754 - accuracy: 0.8742 - val_loss: 0.4166 - val_accuracy: 0.9141
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3789 - accuracy: 0.9088
# Epoch 6: val_accuracy improved from 0.91406 to 0.95703, saving model to best_model.h5
# 10/10 [==============================] - 15s 2s/step - loss: 0.3789 - accuracy: 0.9088 - val_loss: 0.1779 - val_accuracy: 0.9570
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9623
# Epoch 7: val_accuracy improved from 0.95703 to 0.98047, saving model to best_model.h5
# 10/10 [==============================] - 15s 2s/step - loss: 0.1890 - accuracy: 0.9623 - val_loss: 0.1620 - val_accuracy: 0.9805
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9623
# Epoch 8: val_accuracy did not improve from 0.98047
# 10/10 [==============================] - 15s 2s/step - loss: 0.1682 - accuracy: 0.9623 - val_loss: 0.0674 - val_accuracy: 0.9805
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 0.9717
# Epoch 9: val_accuracy improved from 0.98047 to 0.98438, saving model to best_model.h5
# 10/10 [==============================] - 15s 2s/step - loss: 0.0808 - accuracy: 0.9717 - val_loss: 0.0760 - val_accuracy: 0.9844
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9717
# Epoch 10: val_accuracy did not improve from 0.98438
# 10/10 [==============================] - 14s 1s/step - loss: 0.1138 - accuracy: 0.9717 - val_loss: 0.0523 - val_accuracy: 0.9844
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9654
# Epoch 11: val_accuracy did not improve from 0.98438
# 10/10 [==============================] - 14s 1s/step - loss: 0.1543 - accuracy: 0.9654 - val_loss: 0.0443 - val_accuracy: 0.9766
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1577 - accuracy: 0.9563
# Epoch 12: val_accuracy did not improve from 0.98438
# 10/10 [==============================] - 14s 1s/step - loss: 0.1577 - accuracy: 0.9563 - val_loss: 0.0748 - val_accuracy: 0.9688
# Epoch 12: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("D:\\Face Emotion recognition\\Emotion-detection\\best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "/content/test/angry/PrivateTest_1054527.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
#  the image is of neutral
